# %%
import pandas as pd
import numpy as np

import seaborn as sns

df2 = pd.read_excel(r'Atletas.xlsx')
df = pd.read_csv('Housing.csv')

# %%
import pandas as pd

df2 = pd.read_excel(r'Atletas.xlsx')
df = pd.read_csv('Housing.csv')

print(df)

# %%
pd.isna(df).any()
# Out:
# price               False
# area                False
# bedrooms            False
# bathrooms           False
# stories             False
# mainroad            False
# guestroom           False
# basement            False
# hotwaterheating     False
# airconditioning     False
# parking             False
# prefarea            False
# furnishingstatus    False
# dtype: bool

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.drop(['mainroad','guestroom','basement','hotwaterheating','airconditioning','prefarea','furnishingstatus'],axis = 1)
# Out:
#         price  area  bedrooms  bathrooms  stories  parking
# 0    13300000  7420         4          2        3        2
# 1    12250000  8960         4          4        4        3
# 2    12250000  9960         3          2        2        2
# 3    12215000  7500         4          2        2        3
# 4    11410000  7420         4          1        2        2
# ..        ...   ...       ...        ...      ...      ...
# 540   1820000  3000         2          1        1        2
# 541   1767150  2400         3          1        1        0
# 542   1750000  3620         2          1        1        0
# 543   1750000  2910         3          1        1        0
# 544   1750000  3850         3          1        2        0
#
# [545 rows x 6 columns]

# %%
corr = df.corr(); corr
df2.corr()
# Out:
# <ipython-input-48-dd2b92a6feac>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr(); corr
#           lbm        ht        wt       rcc
# lbm  1.000000  0.711327  0.939180  0.085242
# ht   0.711327  1.000000  0.715064  0.014603
# wt   0.939180  0.715064  1.000000  0.020549
# rcc  0.085242  0.014603  0.020549  1.000000

# %%
kend = df.corr(method='kendall'); kend
# Out:
# <ipython-input-49-80f7eb500fa3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   kend = df.corr(method='kendall'); kend
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.422227  0.306770   0.393023  0.286133  0.282781
# area       0.422227  1.000000  0.135422   0.174605  0.047193  0.275404
# bedrooms   0.306770  0.135422  1.000000   0.355017  0.450376  0.131042
# bathrooms  0.393023  0.174605  0.355017   1.000000  0.289585  0.164047
# stories    0.286133  0.047193  0.450376   0.289585  1.000000  0.016622
# parking    0.282781  0.275404  0.131042   0.164047  0.016622  1.000000

# %%
spear = df.corr(method='spearman'); spear#relaciones monotonas
# Out:
# <ipython-input-50-1b4a8e05eea5>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   spear = df.corr(method='spearman'); spear#relaciones monotonas
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.602859  0.390454   0.479912  0.362856  0.365372
# area       0.602859  1.000000  0.176198   0.213793  0.057768  0.353259
# bedrooms   0.390454  0.176198  1.000000   0.377148  0.504291  0.146780
# bathrooms  0.479912  0.213793  0.377148   1.000000  0.308769  0.173982
# stories    0.362856  0.057768  0.504291   0.308769  1.000000  0.018389
# parking    0.365372  0.353259  0.146780   0.173982  0.018389  1.000000

# %%
corr, kend, spear
corr = corr.to_numpy()
spear = spear.to_numpy()

# %%
corr[corr>=spear],spear[corr<spear]
corr>spear #se puede mirar si se puede
# si los xi > corr, la relacion

# %%
sns.pairplot(df) 
# con base a esto se puede decidir si incluir o no variables en el modelo, ya en este punto
# en esta parte debemos elaborar arto

# %%
sns.pairplot(df2)

# %%
# rcc se mira si es sifnificativo por prueba de hipotesis

# %%
from sklearn import linear_model
clf = linear_model.LinearRegression()
clf.fit(Housing)

# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats

diabetes = datasets.load_diabetes()
X = df.to_numpy()
y = df.

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-65-6efc6004f60a> in <module>
# ----> 1 from sklearn import linear_model
#       2 clf = linear_model.LinearRegression()
#       3 clf.fit(Housing)
#
# ModuleNotFoundError: No module named 'sklearn'
